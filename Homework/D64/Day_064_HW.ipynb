# %%
#import required libraries 
#import OpenCV library
import cv2
#import matplotlib library
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# cv2.cvtColor is an OpenCV function to convert images to different color spaces
def convertToRGB(img): 
    return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
def detect_faces(f_cascade, colored_img, scaleFactor = 1.1, minNeighbors = 5):
 #just making a copy of image passed, so that passed image is not changed 
 img_copy = colored_img.copy()          
 
 #convert the test image to gray image as opencv face detector expects gray images
 gray = cv2.cvtColor(img_copy, cv2.COLOR_BGR2GRAY)          
 
 #let's detect multiscale (some images may be closer to camera than others) images
 faces = f_cascade.detectMultiScale(gray, scaleFactor=scaleFactor, minNeighbors=minNeighbors);          
 
 #go over list of faces and draw them as rectangles on original colored img
 for (x, y, w, h) in faces:
      cv2.rectangle(img_copy, (x, y), (x+w, y+h), (0, 255, 0), thickness = 5)              
        
 return img_copy, len(faces)

# %% [markdown]
# # 作業:
# 1. 使用faces = haar_face_cascade.detectMultiScale(gray_img, scaleFactor=1.1, minNeighbors=5);
# 修改 scaleFactor, minNeighbor兩個參數計算 test5.jpg 有幾張臉
#
# 2. load cascade classifier training file for haarcascade
# 3. load cascade classifier training file for lbpcascade

# %%
# 載入圖片 test5.jpg
test5 = cv2.imread('../../data/6/test5.jpg')

# parameter
# scaleFactor：表示在前后两次相继的扫描中，搜索窗口的比例系数。默认为 1.1 即每次搜索窗口依次扩大10%;
# minNeighbors : 表示构成检测目标的相邻矩形的最小个数(默认为3个)。
#                如果组成检测目标的小矩形的个数和小于 min_neighbors - 1 都会被排除。
#                如果min_neighbors 为 0, 则函数不做任何操作就返回所有的被检候选矩形框，
#                这种设定值一般用在用户自定义对检测结果的组合程序上；

params = {
    'scaleFactor': [0.9, 1.1, 1.2],
    'minNeighbors': [1, 3, 6],
}

# %%
#load cascade classifier training file for haarcascade 
haar_face_cascade = cv2.CascadeClassifier('../../data/6/haarcascade_frontalface_alt.xml')

for sf in params['scaleFactor']:
    for mN in params['minNeighbors']:
        faces, count = detect_faces(haar_face_cascade, test5, scaleFactor = 1.1, minNeighbors = 5)
        print('scaleFactor = %f, minNeighbors = %d, Faces found: %d' %(sf, mN, count))
        plt.imshow(convertToRGB(faces))
        plt.show()
# Out:
# scaleFactor = 0.900000, minNeighbors = 1, Faces found: 4
# scaleFactor = 0.900000, minNeighbors = 3, Faces found: 4
# scaleFactor = 0.900000, minNeighbors = 6, Faces found: 4
# scaleFactor = 1.100000, minNeighbors = 1, Faces found: 4
# scaleFactor = 1.100000, minNeighbors = 3, Faces found: 4
# scaleFactor = 1.100000, minNeighbors = 6, Faces found: 4
# scaleFactor = 1.200000, minNeighbors = 1, Faces found: 4
# scaleFactor = 1.200000, minNeighbors = 3, Faces found: 4
# scaleFactor = 1.200000, minNeighbors = 6, Faces found: 4

# %%
#load cascade classifier training file for lbpcascade
lbp_face_cascade = cv2.CascadeClassifier('../../data/6/lbpcascade_frontalface_improved.xml')

for sf in params['scaleFactor']:
    for mN in params['minNeighbors']:
        faces, count = detect_faces(lbp_face_cascade, test5, scaleFactor = 1.1, minNeighbors = 5)
        print('scaleFactor = %f, minNeighbors = %d, Faces found: %d' %(sf, mN, count))
        plt.imshow(convertToRGB(faces))
        plt.show()
# Out:
# scaleFactor = 0.900000, minNeighbors = 1, Faces found: 3
# scaleFactor = 0.900000, minNeighbors = 3, Faces found: 3
# scaleFactor = 0.900000, minNeighbors = 6, Faces found: 3
# scaleFactor = 1.100000, minNeighbors = 1, Faces found: 3
# scaleFactor = 1.100000, minNeighbors = 3, Faces found: 3
# scaleFactor = 1.100000, minNeighbors = 6, Faces found: 3
# scaleFactor = 1.200000, minNeighbors = 1, Faces found: 3
# scaleFactor = 1.200000, minNeighbors = 3, Faces found: 3
# scaleFactor = 1.200000, minNeighbors = 6, Faces found: 3
